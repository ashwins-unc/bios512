# %% [markdown]
# # Final Project

# %% [markdown]
# **Due December 7th, 2022 (Wednesday)**

# %% [markdown]
# For your final project you will develop a data narrative with a dataset of your choosing. Your data can come from any source. You do not have to comprehensively explore your data. Pick an interesting aspect or two from which to build your narrative.

# %% [markdown]
# ## Requirements

# %% [markdown]
# - At least **three** visualizations. Visualizations can be simple bar charts that total data categories or rich exploratory figures. (*Tables also count as visualizations but you must have at least two charts.*)
# - All of the code should be recorded in your narrative. That is, I should be able to run your notebook code start to finish re-producing each of your outputs without error.
# - At least **two** but no more than **three** paragraphs walking the reader through your analysis.
# - Charts should exhibit your command of `ggplot2/dplyr/forcats/tidyr` with:
#   - sensibly sorted categories,
#   - interpretable labels/axis titles,
#   - useful annotations (when applicable),
#   - adjustments to default chart aesthetics,
#   - appropriate markings (e.g. `geoms`) and encodings.

# %% [markdown]
# ## Notes

# %% [markdown]
# *This project should not take you longer than the time to complete two of our assignments. It is meant to demonstrate that you can build an analysis using `R` and the `Tidyverse` from scratch. Focus your analysis on a small number of data features that you find interesting.*
#
# *Remember all the ways of visualizing distributions (ECDFs, histograms, jitter-ed scatter plots, etc.). These will come in very handy!*

# %%
library('tidyverse')
library("palmerpenguins")
locale = Sys.setlocale('LC_ALL','C')

football = read_delim('https://query.data.world/s/5mwlxfcfj44ssdoq5oml6ristkniwj', delim = ';', col_types = cols())

football %>% head()
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# Warning message:
# “package ‘stringr’ was built under R version 4.2.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#   Date                       Competition Name Home team    Opponent
# 1 samedi 16 f<e9>vrier 2019  Liga             FC Barcelona Real Valladolid
# 2 dimanche 13 janvier 2019   Liga             FC Barcelona Eibar
# 3 samedi 22 d<e9>cembre 2018 Liga             FC Barcelona Celta de Vigo
# 4 samedi 20 octobre 2018     Liga             FC Barcelona Sevilla
# 5 dimanche 23 septembre 2018 Liga             FC Barcelona Girona
# 6 samedi 18 ao<U+0B034CB0>18 Liga             FC Barcelona Alav<e9>s
#   Away team       Minute Score Home Team - When Messi Scored
# 1 Real Valladolid 43     1
# 2 Eibar           53     2
# 3 Celta de Vigo   45     2
# 4 Sevilla         12     2
# 5 Girona          19     1
# 6 Alav<e9>s       90+2   3
#   Score Away Team - When Messi Scored Goal Type  Goal Method Final Game Result
# 1 0                                   Penalty    Left foot   Won
# 2 0                                   Field goal Left foot   Won
# 3 0                                   Field goal Left foot   Won
# 4 0                                   Field goal Left foot   Won
# 5 0                                   Field goal Left foot   Draw
# 6 0                                   Field goal Left foot   Won

# %%
df_summary=football %>%
drop_na() %>%
group_by(`Goal Type`, `Goal Method`) %>%
count()    # calculate the name count for each group

df_summary
# Out:
#    Goal Type  Goal Method n
# 1  Field goal Head          2
# 2  Field goal Left foot   102
# 3  Field goal Right foot   16
# 4  Free kick  Left foot    35
# 5  Penalty    Left foot    64
# 6  Rebound    Head          1
# 7  Rebound    Left foot    24
# 8  Rebound    Right foot    7
# 9  Solo run   Left foot    12
# 10 Solo run   Right foot    2

# %%
p = ggplot(df_summary, aes(x = `Goal Method`, y = `n`, fill = `Goal Type`))

p = p + geom_col(position = "dodge")

p
# Out:
# plot without title

# %%
home_team_outcome_summary=football %>%
drop_na() %>%
group_by(`Home team`, `Final Game Result`) %>%
count() %>%
mutate(`Home team` = iconv(`Home team`, to = 'UTF-8'))# calculate the name count for each group

home_team_outcome_summary
##bar chart
#options(repr.plot.width=4, repr.plot.height=3, repr.plot.res = 300)
#p = ggplot(home_team_outcome_summary, aes(x = `Home team`, y = `n`, fill = `Final Game Result`))
#p = p + geom_col()
#p

options(repr.plot.width=6, repr.plot.height=8)

p = ggplot(home_team_outcome_summary, aes( x=`n`, y = `Home team`, fill = `Final Game Result`))

p = p + geom_col()

p
# Out:
#    Home team              Final Game Result n
# 1  AC Milan               Won                 1
# 2  NA                     Won                 3
# 3  Argentina              Draw                1
# 4  Argentina              Won                 5
# 5  Arsenal                Won                 2
# 6  Athletic de Bilbao     Draw                2
# 7  Athletic de Bilbao     Won                 2
# 8  NA                     Won                 3
# 9  Bayer Leverkusen       Draw                1
# 10 Bayer Leverkusen       Won                 1
# 11 NA                     Won                 1
# 12 Celtic                 Lost                1
# 13 Celtic                 Won                 2
# 14 Chelsea                Draw                1
# 15 NA                     Won                 5
# 16 Dynamo Kyiv            Won                 1
# 17 Eibar                  Won                 4
# 18 Elche                  Won                 1
# 19 Espanyol               Won                 4
# 20 FC Barcelona           Draw                9
# 21 FC Barcelona           Lost                4
# 22 FC Barcelona           Won               142
# 23 Getafe                 Won                 2
# 24 Girona                 Won                 1
# 25 Granada                Won                 2
# 26 Las Palmas             Draw                1
# 27 NA                     Won                 2
# 28 Levante                Won                 5
# 29 NA                     Won                 1
# 30 Manchester City        Lost                1
# 31 Manchester City        Won                 1
# 32 Nigeria                Won                 3
# 33 Olympique Lyon         Draw                1
# 34 Osasuna                Won                 3
# 35 PSV Eindhoven          Won                 1
# 36 Racing Santander       Won                 2
# 37 Rayo Vallecano         Won                 3
# 38 Real Betis             Won                 2
# 39 Real Madrid            Draw                1
# 40 Real Madrid            Won                 7
# 41 Real Mallorca          Won                 1
# 42 Real Sociedad          Draw                1
# 43 Real Sociedad          Won                 1
# 44 Real Zaragoza          Won                 2
# 45 Sevilla                Draw                1
# 46 Sevilla                Won                 4
# 47 Shakhtar Donetsk       Won                 1
# 48 Spartak Moscow         Won                 1
# 49 NA                     Won                 4
# 50 Tottenham Hotspur F.C. Won                 2
# 51 NA                     Draw                1
# 52 NA                     Won                 3
# 53 United States          Won                 1
# 54 Valencia               Draw                2
# 55 Valencia               Won                 2
# 56 Viktoria Plzen         Won                 1
# 57 Villarreal             Draw                1
# 58 Villarreal             Won                 1
# plot without title

# %%
away_team_outcome_summary=football %>%
drop_na() %>%
group_by(`Away team`, `Final Game Result`) %>%
count()  %>%
mutate(`Away team` = iconv(`Away team`, to = 'UTF-8'))# calculate the name count for each group

away_team_outcome_summary

##bar chart
options(repr.plot.width=6, repr.plot.height=8)
p = ggplot(away_team_outcome_summary, aes(x = `n`, y = `Away team`, fill = `Final Game Result`))

p = p + geom_col()

p
# Out:
#        Away team           Final Game Result n
# 1      AC Milan            Won                3
# 2      AS Roma             Won                2
# 3      Ajax                Won                1
# 4      NA                  Won                4
# 5      Argentina           Won                4
# 6      Arsenal             Won                4
# 7      Athletic de Bilbao  Won                7
# 8      NA                  Won                4
# 9      Bayer Leverkusen    Won                1
# 10     NA                  Won                1
# 11     Bosnia-Herzegovina  Won                1
# 12     Celta de Vigo       Draw               1
# 13     Celta de Vigo       Won                4
# 14     Celtic              Won                3
# 15     Chelsea             Won                2
# 16     NA                  Draw               1
# 17     NA                  Won                1
# 18     Eibar               Won                7
# 19     Espanyol            Won                9
# 20     FC Barcelona        Draw              13
# 21     FC Barcelona        Lost               2
# 22     FC Barcelona        Won               85
# 23     Getafe              Won                2
# 24     Girona              Draw               1
# 25     Girona              Won                2
# 26     Glasgow Rangers     Won                1
# 27     Granada             Won                6
# 28     Huesca              Won                2
# 29     Juventus            Won                2
# 30     Las Palmas          Won                3
# <U+22EE> <U+22EE>            <U+22EE>          <U+22EE>
# 32     Levante             Won               5
# 33     NA                  Won               3
# 34     Manchester City     Won               3
# 35     Numancia            Won               1
# 36     Olympiacos          Won               1
# 37     Osasuna             Won               3
# 38     PSV Eindhoven       Won               3
# 39     Panama              Won               3
# 40     Paraguay            Draw              1
# 41     Paris Saint-Germain Won               1
# 42     Racing Santander    Draw              1
# 43     Racing Santander    Won               1
# 44     Rayo Vallecano      Won               3
# 45     Real Betis          Lost              2
# 46     Real Betis          Won               8
# 47     Real Madrid         Draw              3
# 48     Real Mallorca       Won               2
# 49     Real Sociedad       Won               4
# 50     Real Valladolid     Won               1
# 51     Real Zaragoza       Won               1
# 52     Recreativo Huelva   Won               1
# 53     Sevilla             Won               8
# 54     NA                  Won               2
# 55     NA                  Won               4
# 56     Valencia            Draw              2
# 57     Valencia            Lost              2
# 58     Valencia            Won               6
# 59     Venezuela           Won               1
# 60     VfB Stuttgart       Won               1
# 61     Villarreal          Won               3
# plot without title
